# %% [markdown]
# Importar e criar a camada

# %%
import sys
import os
sys.path.append(os.path.abspath("../src"))

import numpy as np
from si.neural_networks.layers import Dropout

# %% [markdown]
# Input aleatório

# %%
np.random.seed(42)

X = np.random.rand(5, 10)
X

# %% [markdown]
# Forward propagation - treino

# %%
dropout = Dropout(probability=0.5)

out_train = dropout.forward_propagation(X, training=True)
out_train

# %% [markdown]
# Forward propagation

# %%
out_test = dropout.forward_propagation(X, training=False)
out_test

# %% [markdown]
# Verificar backward propagation

# %%
error = np.ones_like(X)

backprop = dropout.backward_propagation(error)
backprop
